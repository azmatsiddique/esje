# %%
# %load_ext esje

# %%
import esje

# Connect to MySQL (prompts for host, user, password, database)
conn = esje.connect_mysql(
)
# Out:
# Host [localhost]:  192.168.1.7
# Port [3306]:  3306
# Username:  root
# Password:  ········
# Database [optional]:
# Connected to MySQL on 192.168.1.7:3306 as connection 'default'.

# %%
# %%sql
# use class;
# Out:
# 'Query executed successfully (Affected rows: 0)'

# %%
# Quick one-liner query:
# %sql SELECT * FROM sales_data LIMIT 5

# Capture query result directly into a Python DataFrame variable:
df = %sql SELECT country, SUM(revenue) AS total_revenue FROM sales_data GROUP BY country

# %%
df
# Out:
#    country  total_revenue
# 0      USA     1061600.70
# 1   Canada        8400.00
# 2       UK        6200.75
# 3  Germany       11300.00
# 4    India      561400.80
# 5    Japan        9800.00

# %%
# %%sql -o sales_summary
# SELECT
#     category,
#     COUNT(*) AS total_orders,
#     SUM(revenue) AS total_revenue
# FROM sales_data
# GROUP BY category
# ORDER BY total_revenue DESC;
# Out:
#       category  total_orders  total_revenue
# 0        hate1             2      520000.00
# 1     Software             4      311200.80
# 2     hardware             1      260000.00
# 3         love             1      260000.00
# 4         hate             1      260000.00
# 5  Electronics             3       32200.50
# 6    Furniture             2       15300.95

# %%
# %%sql --live
# SELECT category, SUM(revenue) AS total_revenue
# FROM sales_data
# GROUP BY category;
#
# import matplotlib.pyplot as plt
#
# df.plot(
#     x='category',
#     y='total_revenue',
#     kind='bar',
#     title='Total Revenue by Category',
#     color='skyblue',
#     figsize=(8, 4)
# )
# plt.ylabel('Revenue ($)')
# plt.tight_layout()
# plt.show()

# %%
esje.pause_live
# Out:
# <function esje.pause_live(widget_id: str | None = None) -> None>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 esje.start_live()
#
# AttributeError: module 'esje' has no attribute 'start_live'

# %%
import esje

# Opens your browser → Sign in → Done!
conn = esje.connect_bigquery(
    name="bq",
    project="your-gcp-project-id",   # replace with your project
    auth_method="browser"
)
# Out:
# 🔐 esje | Login with Google required.
#    A browser window will open for authentication.
#    After signing in and granting access, return to your notebook.
#
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A54955%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&state=fJ9UkoIjqy76F1kRuA6oEhY0nzxOll&code_challenge=JwlNERkbEBIGcBuZy25mRlRtoZGHhuH4E-1N2ZuUWWM&code_challenge_method=S256&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import esje
#       2
#       3 # Opens your browser → Sign in → Done!
# ----> 4 conn = esje.connect_bigquery(
#       5     name="bq",
# ...

# %%
# !pip3 install 'esje[bigquery]'
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Cell 1 — check which Python Jupyter is using
import sys
print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/bin/python3.14

# %%
# Cell 2 — install into the active Jupyter kernel
import sys
# !{sys.executable} -m pip install --prefer-binary google-auth-oauthlib -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.14/bin/python3.14 -m pip install --upgrade pip

# %%
import esje

# Opens your browser → Sign in → Done!
conn = esje.connect_bigquery(
    name="bq",
    project="qwiklabs-gcp-04-857f73c07760",   # replace with your project
    auth_method="browser"
)
# Out:
# 🔐 esje | Login with Google required.
#    A browser window will open for authentication.
#    After signing in and granting access, return to your notebook.
#
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A55522%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&state=TMZ5w8lbG0IWVTl3Q0eI91eqN3U9pB&code_challenge=WfZsT711Tr0TOfzw6_8GnGEZE14SohqVJZdONkoL3B0&code_challenge_method=S256&access_type=offline
# ✅ Connected to BigQuery project 'qwiklabs-gcp-04-857f73c07760' via browser as connection 'bq'.

# %%
# %%sql
# SELECT 1 AS ping          -- quick connection test
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/google/cloud/bigquery/table.py:2128: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    ping
# 0     1

# %%
import sys
# !{sys.executable} -m pip install --prefer-binary \
    google-auth-oauthlib \
    db-dtypes \
    google-cloud-bigquery \
    "esje[bigquery]" -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.14/bin/python3.14 -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install db-dtypes --prefer-binary -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.14/bin/python3.14 -m pip install --upgrade pip

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS `qwiklabs-gcp-04-857f73c07760.my_database`
# OPTIONS (
#     description = "My first esje dataset",
#     location = "US"
# )
# Out:
# 'BigQuery query executed successfully (Affected rows: 0)'

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS `qwiklabs-gcp-04-857f73c07760.my_database`
# OPTIONS (description = "My first esje dataset")
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS `qwiklabs-gcp-04-857f73c07760.my_database.sales` (
#     id          INT64,
#     product     STRING,
#     category    STRING,
#     quantity    INT64,
#     revenue     FLOAT64,
#     sale_date   DATE
# )
# Out:
# 'BigQuery query executed successfully (Affected rows: 0)'

# %%
# %%sql
# INSERT INTO `qwiklabs-gcp-04-857f73c07760.my_database.sales` VALUES
#     (1, 'Laptop',  'Electronics', 2, 2400.00, '2024-01-10'),
#     (2, 'Phone',   'Electronics', 5, 3500.00, '2024-01-11'),
#     (3, 'Desk',    'Furniture',   1,  850.00, '2024-01-12'),
#     (4, 'Monitor', 'Electronics', 3, 1200.00, '2024-01-13'),
#     (5, 'Chair',   'Furniture',   4, 1600.00, '2024-01-14')
# Out:
# 'BigQuery query executed successfully (Affected rows: 0)'

# %%
# %%sql
# show tables;
# Out:
# Error: BigQuery Query Error: 400 Statement not supported: ShowStatement at [1:1]; reason: invalidQuery, location: query, message: Statement not supported: ShowStatement at [1:1]
#
# Location: US
# Job ID: 413fc0e1-7bef-43a9-a965-9ae6a96f867f

# %%
# %%sql -c bq
# INSERT INTO `qwiklabs-gcp-04-857f73c07760.my_database.sales` VALUES
#     (1, 'Laptop',  'Electronics', 2, 2400.00, '2024-01-10'),
#     (2, 'Phone',   'Electronics', 5, 3500.00, '2024-01-11'),
#     (3, 'Desk',    'Furniture',   1,  850.00, '2024-01-12'),
#     (4, 'Monitor', 'Electronics', 3, 1200.00, '2024-01-13'),
#     (5, 'Chair',   'Furniture',   4, 1600.00, '2024-01-14')
# Out:
# 'BigQuery query executed successfully (Affected rows: 0)'
